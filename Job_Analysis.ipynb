# %% [markdown]
# <a href="https://colab.research.google.com/github/Asvikap/Job_Analysis/blob/main/Job_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import pandas as pd

# %%
#df = pd.read_csv('/content/drive/MyDrive/data_science_job.csv')

df = pd.read_csv('/content/drive/MyDrive/data_science_job.csv', encoding='latin-1')


df
# Out:
#               Company                                    Job Title  \
# 0                 SGS                        Clinical Data Analyst
# 1             Ocorian                       AML/CFT & Data Analyst
# 2              Cricut                    Machine Learning Engineer
# 3         Bosch Group         Application Developer & Data Analyst
# 4     Publicis Groupe  Data Engineer Full time (Public Sector) USA
# ...               ...                                          ...
# 3193  Western Digital        Data Scientist - New College Graduate
# 3194         Experian                           Cloud Data Analyst
# 3195   Locus Robotics                   Robotics Engineer, Sensors
# 3196    ATB Financial                               Data Scientist
# 3197          Shippeo                         Senior Data Engineer
#
#                              Location   Job Type Experience level    Salary  \
# 0       Richardson, TX, United States  Full Time      Entry-level    48K+ *
# ...

# %%
df.columns
# Out:
# Index(['Company', 'Job Title', 'Location', 'Job Type', 'Experience level',
#        'Salary', 'Requirment of the company ', 'Facilities'],
#       dtype='object')

# %%
import matplotlib as plt
import seaborn as sn

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3198 entries, 0 to 3197
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Company                     3197 non-null   object
#  1   Job Title                   3197 non-null   object
#  2   Location                    3197 non-null   object
#  3   Job Type                    3197 non-null   object
#  4   Experience level            2962 non-null   object
#  5   Salary                      3009 non-null   object
#  6   Requirment of the company   3198 non-null   object
#  7   Facilities                  3198 non-null   object
# dtypes: object(8)
# memory usage: 200.0+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3198 entries, 0 to 3197
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Company                     3197 non-null   object
#  1   Job Title                   3197 non-null   object
#  2   Location                    3197 non-null   object
#  3   Job Type                    3197 non-null   object
#  4   Experience level            2962 non-null   object
#  5   Salary                      3009 non-null   object
#  6   Requirment of the company   3198 non-null   object
#  7   Facilities                  3198 non-null   object
# dtypes: object(8)
# memory usage: 200.0+ KB

# %%
df.describe()
# Out:
#                 Company      Job Title          Location   Job Type  \
# count              3197           3197              3197       3197
# unique             1106           2138              1117          3
# top     Publicis Groupe  Data Engineer  Bengaluru, India  Full Time
# freq                126            105                90       3116
#
#        Experience level    Salary  \
# count              2962      3009
# unique                4       218
# top        Senior-level   115K+ *
# freq               1876       253
#
#                                Requirment of the company  Facilities
# count                                                3198       3198
# unique                                               2600        777
# top     Big Data,Business Intelligence,Data analysis,E...       ,,,,
# freq                                                   12        542

# %%
df.duplicated().sum()
# Out:
# 202

# %%
df1 = df.dropna()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2777 entries, 0 to 3197
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Company                     2777 non-null   object
#  1   Job Title                   2777 non-null   object
#  2   Location                    2777 non-null   object
#  3   Job Type                    2777 non-null   object
#  4   Experience level            2777 non-null   object
#  5   Salary                      2777 non-null   object
#  6   Requirment of the company   2777 non-null   object
#  7   Facilities                  2777 non-null   object
# dtypes: object(8)
# memory usage: 195.3+ KB

# %%
df1.isnull().sum()
# Out:
# Company                       0
# Job Title                     0
# Location                      0
# Job Type                      0
# Experience level              0
# Salary                        0
# Requirment of the company     0
# Facilities                    0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 177

# %%
df.columns
# Out:
# Index(['Company', 'Job Title', 'Location', 'Job Type', 'Experience level',
#        'Salary', 'Requirment of the company ', 'Facilities'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['Company', 'Job Title', 'Location', 'Job Type', 'Experience level',
#        'Salary', 'Requirment of the company ', 'Facilities'],
#       dtype='object')

# %%
df['Job Title'].value_counts()
# Out:
# Data Engineer                                                                    105
# Data Scientist                                                                    82
# Data Analyst                                                                      79
# Senior Data Engineer                                                              67
# Machine Learning Engineer                                                         47
#                                                                                 ...
# Director | Master Data Management Delivery Lead| Data & Cloud - NV1 Clearance      1
# Senior Data Engineer -REMOTE                                                       1
# Associate Director/Director of Chemical Data Analytics                             1
# AI Engineer                                                                        1
# Data Scientist - New College Graduate                                              1
# ...

# %%
df['Location'].value_counts()
# Out:
# Bengaluru, India                             90
# Paris, France                                79
# New York City, United States                 69
# Remote                                       67
# London, United Kingdom                       64
#                                              ..
# Redwood City, USA & Vancouver, Canada &
#      1
# Remote Canada | Remote United States          1
# Toronto, ON                                   1
# Mountain View, CA, United States              1
# Biñan, Philippines                            1
# Name: Location, Length: 1117, dtype: int64

# %%
df['Company'].value_counts()
# Out:
# Publicis Groupe                   126
# Bosch Group                       102
# Amazon.com                         57
# Block                              54
# Visa                               44
#                                  ...
# PayFit                              1
# Pindrop                             1
# SMRS                                1
# Funding Societies                   1
# Galileo Financial Technologies      1
# Name: Company, Length: 1106, dtype: int64

# %%
df['Job Type'].value_counts()
# Out:
# Full Time     3116
# Internship      75
# Part Time        6
# Name: Job Type, dtype: int64

# %%
df['Salary'].value_counts()
# Out:
#  115K+ *    253
#  62K+ *     217
#  92K+ *     204
#  129K+ *    163
#  55K+ *     159
#            ...
# GBP 42K+      1
# EUR 80K+      1
#  214K+        1
#  63K+         1
#  117K+        1
# Name: Salary, Length: 218, dtype: int64

# %%
df['Experience level'].value_counts()
# Out:
# Senior-level       1876
# Entry-level         506
# Mid-level           452
# Executive-level     128
# Name: Experience level, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
sn.countplot(data = df, x = 'Experience level')
plt.title('Experience level')
plt.show()

# %%
plt.figure(figsize=(20,8))
df1['Company'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Company'>

# %%
location_counts = df['Location'].value_counts().head(30)

plt.figure(figsize=(20,10))
location_counts.plot(kind='bar')
plt.title('Top 30 Locations')
plt.xlabel('Location')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
location_counts = df['Job Title'].value_counts().head(5)


plt.figure(figsize=(20,8))
location_counts.plot(kind='bar')
plt.title('Top 5 Job Title')
plt.xlabel('Job Title')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
location_counts = df['Company'].value_counts().head(40)

# Plotting the bar graph
plt.figure(figsize=(20,8))
location_counts.plot(kind='bar')
plt.title('Top 40 Company')
plt.xlabel('Company')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
location_counts = df['Salary'].value_counts().head(30)

# Plotting the bar graph
plt.figure(figsize=(20,8))
location_counts.plot(kind='bar')
plt.title('Top 30 Salary Category')
plt.xlabel('Salary Category')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
df1.head()
# Out:
#            Company                                    Job Title  \
# 0              SGS                        Clinical Data Analyst
# 1          Ocorian                       AML/CFT & Data Analyst
# 3      Bosch Group         Application Developer & Data Analyst
# 4  Publicis Groupe  Data Engineer Full time (Public Sector) USA
# 5       ServiceNow                Sr Staff Data Scientist - ATG
#
#                               Location   Job Type Experience level   Salary  \
# 0        Richardson, TX, United States  Full Time      Entry-level   48K+ *
# 1                     Ebène, Mauritius  Full Time      Entry-level   48K+ *
# 3                     Nonantola, Italy  Full Time      Entry-level   48K+ *
# 4         Arlington, VA, United States  Full Time        Mid-level    108K+
# 5  Kirkland, Washington, United States  Full Time     Senior-level    184K+
#
#                           Requirment of the company   \
# 0  Computer Science,Data quality,Genetics,Mathema...
# ...

# %%
df1['Facilities']
# Out:
# 0                                                    ,,,,
# 1                                                    ,,,,
# 3                                                    ,,,,
# 4       Flex hours,Flex vacation,Parental leave,Unlimi...
# 5       401(k) matching,Career development,Competitive...
#                               ...
# 3193                               Career development,,,,
# 3194                  Equity,Medical leave,Salary bonus,,
# 3195                                                 ,,,,
# 3196            Career development,Startup environment,,,
# 3197                                                 ,,,,
# Name: Facilities, Length: 2777, dtype: object

# %%
new_df = df.Facilities.str.split(",",expand=True)

# %%
new_df.head()
# Out:
#                     0              1               2                        3  \
# 0
# 1
# 2  Career development
# 3
# 4          Flex hours  Flex vacation  Parental leave  Unlimited paid time off
#
#   4
# 0
# 1
# 2
# 3
# 4

# %%
df.columns = ['Company', 'Job Title', 'Location', 'Job Type', 'Experience level', 'Salary', 'Requirements', 'Facilities']

# Print the updated DataFrame
df.head()
# Out:
#            Company                                    Job Title  \
# 0              SGS                        Clinical Data Analyst
# 1          Ocorian                       AML/CFT & Data Analyst
# 2           Cricut                    Machine Learning Engineer
# 3      Bosch Group         Application Developer & Data Analyst
# 4  Publicis Groupe  Data Engineer Full time (Public Sector) USA
#
#                           Location   Job Type Experience level   Salary  \
# 0    Richardson, TX, United States  Full Time      Entry-level   48K+ *
# 1                 Ebène, Mauritius  Full Time      Entry-level   48K+ *
# 2  South Jordan, UT, United States  Full Time              NaN   90K+ *
# 3                 Nonantola, Italy  Full Time      Entry-level   48K+ *
# 4     Arlington, VA, United States  Full Time        Mid-level    108K+
#
#                                         Requirements  \
# 0  Computer Science,Data quality,Genetics,Mathema...
# ...

# %%
df1 = df.Requirements.str.split(",",expand=True)

# %%
df1.head()
# Out:
#                   0                1                 2                 3  \
# 0  Computer Science     Data quality          Genetics       Mathematics
# 1             Agile  Data management           Finance          Security
# 2             Agile     Architecture               AWS  Computer Science
# 3       Engineering       Industrial            Oracle          Power BI
# 4               AWS            Azure  Computer Science        Consulting
#
#                  4               5
# 0              SAS      Statistics
# 1
# 2  Computer Vision   Deep Learning
# 3                R             R&D
# 4         Dataflow  Data pipelines

# %%
df_Requirment = df.groupby('Experience level')['Requirements'].apply(lambda x: ''.join(x)).reset_index()

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud

# %%
df_WordCloud = df_Requirment[df_Requirment['Experience level'] == data]
text_data =  df_WordCloud['Requirements'].str.cat(sep=', ')

# Generate the word cloud
#wordcloud = WordCloud(background_color='White').generate(text_data)
#wordcloud = WordCloud(background_color='white').generate(text_data)
wordcloud = WordCloud(colormap='viridis').generate(text_data)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title(f'WordCloud for {data}', pad = 20, size = 16)
plt.axis('off')
plt.show()
